# %% [markdown]
# # Демо-версия задания к зачету по дисциплине "Основы программирования на языке Python"

# %% [markdown]
# **Реализуйте класс «Воздушный Замок» (`AirCastle`)**
#
# Экземпляр класса инициализируется с аргументами:
# * высота;
# * количество составляющих облаков;
# * цвет.
#
# Класс должен реализовывать методы:
# * `change_height(value)` – изменить высоту на `value`, может уменьшаться только до нуля;
# * сложить с числом, добавляется `n` облаков к замку, одновременно увеличивается высоту на `n // 5`;
# * экземпляр класса можно вызвать с аргументом – целым числом, означающим прозрачность облаков; метод возвращает значение видимости замка, рассчитанное по формуле: `высота // прозрачность * количество облаков`;
# * `__str__` – возвращает строковое представление в виде: `“The AirCastle at an altitude of <высота> meters is <цвет> with <количество облаков> clouds”`.
# * экземпляры можно сравнивать: сначала по количеству облаков, затем по высоте, затем по цвету по алфавиту; для этого нужно реализовать методы сравнения: `>, <, >=, <=, ==, !=`.

# %%
class AirCastle:
    ### YOUR CODE HERE
    raise NotImplementedError

# %% [markdown]
# В файле `castles.txt` построчно содержится информация о каждом замке в виде 2 чисел: высоты, количества облаков и строки, обозначающей цвет. Считайте файл и постройте список всех замков. Отсортируйте список в порядке возрастания (используя функции сравнения класса).

# %%
### YOUR CODE HERE

# %% [markdown]
# В файле `operations.txt` содержится список действий, которые необходимо выполнить со списком замков. В каждой строке через пробел содержатся несколько значений:
# 1. номер замка в списке;
# 2. операция;
# 3. параметр для операции
#
# Номера операций:
# 1. изменений высоты
# 2. сложение с числом
# 3. вызов объекта класса
# 4. печать строкового представления (в данном случае параметр отсутствует)
#
# Считайте данный файл и выполните последовательно все операции.

# %%
### YOUR CODE HERE
